# %%
import pandas as pd
import datetime as dt

# %% [markdown]
# # Задание 1

# %%
string_ = """The Moscow Times - Wednesday, October 2, 2002
The Guardian - Friday, 11.10.13
Daily News - Thursday, 18 August 1977
# доп
The Moscow Times - Sunday, October 2, 2003"""

# %%
for i in enumerate(string_.split("\n")):
    matcher, info = i
    match matcher:
        case x if "Moscow" in info.split("- ")[0]:
            dt_object = dt.datetime.strptime(info.split("- ")[1], "%A,  %B %d,  %Y")
            print(dt_object)
        case y if "Guardian" in info.split("- ")[0]:
            dt_object = dt.datetime.strptime(info.split("- ")[1], "%A,  %d.%m.%y")
            print(dt_object)
        case z if "Daily News" in info.split("- ")[0]:
            dt_object = dt.datetime.strptime(info.split("- ")[1], "%A,  %d %B %Y")
            print(dt_object)
# Out:
# 2002-10-02 00:00:00
# 2013-10-11 00:00:00
# 1977-08-18 00:00:00
# 2003-10-02 00:00:00

# %% [markdown]
# # Задание 2

# %%
def date_range (start_date:str, end_date:str) -> list:
    answer = []
    format_ = "%Y-%m-%d"
    try:
        start_date, end_date = dt.datetime.strptime(start_date, format_), dt.datetime.strptime(end_date, format_)
    except:
        return answer
    if end_date < start_date:
        return answer
    else:
        answer.append(start_date.strftime(format_))
        timedelta_ = end_date - start_date
        for i in range(0, int(str(timedelta_).split(" ")[0])):
            start_date += dt.timedelta(days=1)
            answer.append(start_date.strftime(format_))
        return answer

# %%
date_range('2022-01-01', '2022-01-03')
# Out:
# ['2022-01-01', '2022-01-02', '2022-01-03']

# %%
date_range('2022-01-03', '2022-01-01')
# Out:
# []

# %%
date_range('2022-02-30', '2022-02-31')
# Out:
# []
